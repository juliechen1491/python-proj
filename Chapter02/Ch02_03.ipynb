# %% [markdown]
# # Selenium 教學 1｜告牌匯率爬蟲
#
# 瀏覽器驅動程式（WebDriver）<br>
# Chrome：https://chromedriver.chromium.org/downloads<br>
# Edge：https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/<br>
# Firefox：https://github.com/mozilla/geckodriver/releases<br>
# Safari：https://webkit.org/blog/6900/webdriver-support-in-safari-10/<br>

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome(executable_path='./chromedriver')
driver.implicitly_wait(20)
driver.get(url='https://bank.sinopac.com/mma8/bank/html/rate/bank_ExchangeRate.html')

html_source = driver.page_source
driver.quit()

# %%
html_source
# Out:
# '<html lang="zh-TW"><head><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script>\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n    <link rel="shortcut icon" href=" https://mma.sinopac.com/images/favicon.ico ">\n    <title>永豐銀行 Bank SinoPac-資訊看板-牌告匯率</title>\n    <link href="/MMA8/bank/css/reset.css" rel="stylesheet" type="text/css">\n    <link href="/MMA8/bank/css/jquery-ui.css" rel="stylesheet" type="text/css">\n    <link href="/MMA8/bank/css/site.css" rel="stylesheet" type="text/css">\n    <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-WQNGCJN"></script><script async="" src="https://dmp.sinopac.com/DMP_SA/SDK/Scripts/sensorsdata.min.securejs"></script><script src="/MMA8/bank/js/jquery-latest.min.securejs" type="text/javascript"></script>\n    <script src="/MMA8/bank/js/jquery-ui.js" type="text/javascript"></script>\n    <script src="/MMA8/bank/js/fancyfields-1.2.min.js" type="text/javascript"></script>\n\t<script src="/MMA8/bank/js/jquery.pagination.js" type="text/javascript"></script>\n    <script src="/MMA8/bank/js/site.js" type="text/javascript"></script>\n    <script src="/MMA8/bank/js/bank.sinopac.common.js" type="text/javascript" language="javascript"></script>\n\t<script src="/MMA8/bank/js/sensorstracker_rate.js" type="text/javascript"></script>\n\t<!-- Google Tag Manager -->\n\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t})(window,document,\'script\',\'dataLayer\',\'GTM-WQNGCJN\');</script>\n\t<!-- End Google Tag Manager -->\n\t<style>.noacct { text-align: center;font-size: 14pt;font-family:微軟正黑體; height: 373px;width: 866px;color: #ff0000;}</style>\n    <script type="text/javascript" language="javascript">\n        var mmahost = "https://mma.sinopac.com";\n        var bankhost = "https://bank.sinopac.com";\n\t\n    var Type;\n\tvar ETSLISTARR = [];\n\tvar members = [];\n    var pagelines = 40;\n    var BaseFlag = "00"; // 00:臺幣 ; 01:美金\n    var SelectToday = false;\n\t\n\t//GET DATE\n\tvar Today = [new Date().getFullYear(), (new Date().getMonth()+1), new Date().getDate()].join(\'/\');\n\tvar someDate = new Date(Today);\n\tsomeDate.setDate(someDate.getDate() - 1);\n\tvar Yesterday = [someDate.getFullYear(), (someDate.getMonth()+1), someDate.getDate()].join(\'/\');\n\t\n    $(document).ready(function() {\n        doREMIT();\n        setTimeout(doCASH, 500);\n\t\t//();\n\t\tYesterday = ChangeDFormate(Yesterday);\n\n        $(\'#SearchPair li\').click(function(e){\n            e.preventDefault();\n            CheckPair(this);\n        });\n\t\t\n        //試算金額顯示\n        $(\'.resultblock\').hide();\n    });\n    function doREMIT() {\n        var url = mmahost + "/ws/share/rate/ws_exchange.ashx?exchangeType=REMIT&Cross=genREMITResult";\n        var dataType = "json";\n        var MEMOURL = "";\n        var TimeoutMessage = "";\n        document.getElementById(\'TInfo\').innerHTML = "本資訊僅供參考，實際成交匯率以本行牌告交易當下所議定的匯率為準。";\n        JQCommon_sendCrossAjax(url, dataType, true, false, "genREMITResult");\n     }\n     function genREMITResult(sJson) {\n\t\tvar JsonObj=sJson;\n        if (JsonObj[0]["Header"] == "SUCCESS") {\n            var s_date = JsonObj[0]["TitleInfo"];\n\t\t\tvar s_date_1=s_date.substring(44,25)\n\t\t\t\n            if (document.getElementById(\'tab1_date\') != null) {\n                document.getElementById(\'tab1_date\').innerHTML = s_date_1;\n            }\n            var objSubInfo = JsonObj[0]["SubInfo"];\n            \n            for (i = 0; i < objSubInfo.length; i++) {\n                var item=objSubInfo[i]["DataValue1"];\n                var buy=objSubInfo[i]["DataValue2"];\n                var sale=objSubInfo[i]["DataValue3"];\n      ...

# %%
soup = BeautifulSoup(html_source, 'lxml')

# %%
table = soup.select('table')[0]

# %%
for tr in table.select('tr')[2:]:
    print(tr.div.text)
    for td in tr.select('.bwc10'):
        print(td.text)
# Out:
# 美金(USD)
# 30.3030
# 30.4450
# 30.1030
# 30.6450
# 日圓(JPY)
# 0.2736
# 0.2777
# 0.2706
# 0.2792
# 港幣(HKD)
# 3.8862
# 3.9450
# 3.8462
# 3.9850
# 歐元(EUR)
# 32.3730
# 32.7700
# 32.0230
# 33.1200
# 英鎊(GBP)
# 35.3220
# 35.7110
# -
# -
# 瑞士法郎(CHF)
# 30.7270
# 30.9990
# -
# -
# 澳幣(AUD)
# 17.3730
# 17.5900
# -
# -
# 新加坡幣(SGD)
# 20.7540
# 20.9320
# -
# -
# 瑞典幣(SEK)
# 2.9066
# 2.9536
# -
# -
# 加幣(CAD)
# 20.9130
# 21.0760
# -
# -
# 泰銖(THB)
# 0.8999
# 0.9426
# -
# -
# 南非幣(ZAR)
# 1.6770
# 1.7308
# -
# -
# 紐西蘭幣(NZD)
# 16.9850
# 17.2040
# -
# -
# 澳門幣(MOP)
# 3.7328
# 3.8722
# -
# -
# 人民幣(CNY)
# 4.2262
# 4.2952
# 4.1662
# 4.3152
# 離岸人民幣(CNH)
# 4.2256
# 4.2800
# -
# -

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome(executable_path='./chromedriver')
driver.implicitly_wait(20)
driver.get(url='https://bank.sinopac.com/mma8/bank/html/rate/bank_ExchangeRate.html')

html_source = driver.page_source
driver.quit()

soup = BeautifulSoup(html_source, 'lxml')
table = soup.select('table')[0]

for tr in table.select('tr')[2:]:
    print(tr.div.text)
    for td in tr.select('.bwc10'):
        print(td.text)
# Out:
# 美金(USD)
# 30.3030
# 30.4450
# 30.1030
# 30.6450
# 日圓(JPY)
# 0.2736
# 0.2777
# 0.2706
# 0.2792
# 港幣(HKD)
# 3.8862
# 3.9450
# 3.8462
# 3.9850
# 歐元(EUR)
# 32.3730
# 32.7700
# 32.0230
# 33.1200
# 英鎊(GBP)
# 35.3220
# 35.7110
# -
# -
# 瑞士法郎(CHF)
# 30.7270
# 30.9990
# -
# -
# 澳幣(AUD)
# 17.3730
# 17.5900
# -
# -
# 新加坡幣(SGD)
# 20.7540
# 20.9320
# -
# -
# 瑞典幣(SEK)
# 2.9066
# 2.9536
# -
# -
# 加幣(CAD)
# 20.9130
# 21.0760
# -
# -
# 泰銖(THB)
# 0.8999
# 0.9426
# -
# -
# 南非幣(ZAR)
# 1.6770
# 1.7308
# -
# -
# 紐西蘭幣(NZD)
# 16.9850
# 17.2040
# -
# -
# 澳門幣(MOP)
# 3.7328
# 3.8722
# -
# -
# 人民幣(CNY)
# 4.2262
# 4.2952
# 4.1662
# 4.3152
# 離岸人民幣(CNH)
# 4.2256
# 4.2800
# -
# -
